# %%
import requests
import pandas as pd

# %% [markdown]
# ## 1. Extraction of German University Fees

# %%
de_fees = pd.read_csv('de_fees.csv', index_col = 0)
de_fees = de_fees.drop("Inkludiertes Semesterticket", axis=1)
de_fees = de_fees.drop("Prozentualer Anteil des Semestertickets", axis= 1)
de_fees["Semesterbeitrag 2019_per_year"]= de_fees["Semesterbeitrag 2019"]*2
de_fees["Semesterbeitrag 2020_per_year"]= de_fees["Semesterbeitrag 2020"]*2
de_fees = de_fees.drop("Semesterbeitrag 2019_per_year", axis= 1)
de_fees = de_fees.drop("Semesterbeitrag 2020_per_year", axis= 1)

# %%
de_fees
# Out:
#                                                     Semesterbeitrag 2019  \
# Hochschule
# Leibniz Universität Hannover                                      408.47
# Technische Universität Carolo-Wilhelmina zu Bra...                358.77
# Georg-August-Universität Göttingen                                355.31
# Johann Wolfgang Goethe-Universität Frankfurt am...                366.71
# Philipps-Universität Marburg                                      336.73
# Ruhr-Universität Bochum                                           332.00
# Universität Hamburg                                               328.00
# Johannes Gutenberg-Universität Mainz                              322.18
# Universität Duisburg-Essen                                        313.18
# Universität Paderborn                                             311.38
# Humboldt-Universität zu Berlin                                    315.64
# Technische Universität Dortmund                                   299.22
# ...

# %%
#Ideas: de_fees["average de_fee_yr"]

# %% [markdown]
# ## 2. Extraction of English University Fees

# %%
df = pd.read_csv('eng_unis.txt')
df
# Out:
# Empty DataFrame
# ...

# %%
universities = ["AECC University College","Anglia Ruskin University","Arden University","Arts University Bournemouth","University of the Arts London","Aston University","University of Bath","Bath Spa University","University of Bedfordshire","University of Birmingham","University College Birmingham","Birmingham City University","Bishop Grosseteste University","University of Bolton","Bournemouth University","BPP University","University of Bradford","University of Brighton","University of Bristol","Brunel University London","University of Buckingham","Buckinghamshire New University","University of Cambridge","Canterbury Christ Church University","University of Central Lancashire","University of Chester","University of Chichester","Coventry University","Cranfield University","University for the Creative Arts","University of Cumbria","De Montfort University","University of Derby","Durham University","University of East Anglia","University of East London","Edge Hill University","University of Essex","University College of Estate Management","University of Exeter","Falmouth University","University of Gloucestershire","University of Greenwich","Harper Adams University","Hartpury University","University of Hertfordshire","University of Huddersfield","University of Hull","Imperial College London","Keele University","University of Kent","Kingston University","Lancaster University","University of Law","University of Leeds","Leeds Arts University","Leeds Beckett University","Leeds Trinity University","University of Leicester","University of Lincoln","University of Liverpool","Liverpool Hope University","Liverpool John Moores University","University of London","â†’ Birkbeck, University of London","â†’ City, University of London","â†’ Courtauld Institute of Art","â†’ Goldsmiths, University of London","â†’ Heythrop College","â†’ Institute of Cancer Research","â†’ King's College London","â†’ London Business School","â†’ London School of Economics","â†’ London School of Hygiene & Tropical Medicine","â†’ Queen Mary, University of London","â†’ Royal Academy of Music","â†’ Royal Central School of Speech and Drama","â†’ Royal Holloway, University of London","â†’ Royal Veterinary College","â†’ St George's, University of London","â†’ School of Oriental and African Studies","â†’ University College London","London Institute of Banking & Finance","London Metropolitan University","London South Bank University","Loughborough University","University of Manchester","Manchester Metropolitan University","Middlesex University","Newcastle University","Newman University","University of Northampton","Northumbria University","Norwich University of the Arts","University of Nottingham","Nottingham Trent University","Open University","University College of Osteopathy","University of Oxford","Oxford Brookes University","Plymouth University","University of Portsmouth","Ravensbourne University London","University of Reading","Regent's University London","Roehampton University","Royal Agricultural University","University of Salford","University of Sheffield","Sheffield Hallam University","University of Southampton","Southampton Solent University","University of St Mark & St John","St Mary's University, Twickenham","Staffordshire University","University of Suffolk","University of Sunderland","University of Surrey","University of Sussex","Teesside University","University of Warwick","University of West London","University of the West of England","University of Westminster","University of Winchester","University of Wolverhampton","University of Worcester","Writtle University College","University of York","York St John University"]
column = ["eng_unis"]
df = pd.DataFrame({'eng_unis':universities})
df["tuition_fee_yr in pounds"] = 9250

# %%
df["tuition_fee_yr in pounds"] = 9250

# %%
df
# Out:
#                           eng_unis  tuition_fee_yr in pounds
# 0          AECC University College                      9250
# 1         Anglia Ruskin University                      9250
# 2                 Arden University                      9250
# 3      Arts University Bournemouth                      9250
# 4    University of the Arts London                      9250
# ..                             ...                       ...
# 125    University of Wolverhampton                      9250
# 126        University of Worcester                      9250
# 127     Writtle University College                      9250
# 128             University of York                      9250
# 129        York St John University                      9250
#
# [130 rows x 2 columns]

# %%
cities2 = ['Carmarthen, Wales',
 'Bradford, England',
 'Bolton, England',
 'Carlisle, England',
 'Sunderland, England',
 'Preston, England',
 'Middlesbrough, England',
 'Aberystwyth, Wales',
 'Inverness, Scotland',
 'Stoke-on-Trent, England',
 'Huddersfield, England',
 'Newport, Wales',
 'Wolverhampton, England',
 'Luton, England',
 'Ipswich, England',
 'Chester, England',
 'Northampton, England',
 'Leicester, England',
 'Aberdeen, Scotland',
 'Plymouth, England',
 'Belfast, Northern Ireland',
 'Derby, England',
 'Norwich, England',
 'Ormskirk, England',
 'Keele / Newcastle-under-Lyme, England',
 'Swansea, Wales',
 'Buckingham, England',
 'Dundee, Scotland',
 'Worcester, England',
 'High Wycombe, England',
 'Lincoln, England',
 'Liverpool, England',
 'Loughborough, England',
 'Cheltenham, England',
 'Bangor, Wales',
 'Sheffield\xa0, England',
 'Gillingham, England',
 'Lancaster, England',
 'Newcastle-upon-Tyne, England',
 'Stirling, Scotland',
 'Cardiff, Wales',
 'Salford, England',
 'Colchester, England',
 'Hull, England',
 'Canterbury, England',
 'Coventry, England',
 'Hatfield, England',
 'Chichester, England',
 'Cambridge, England',
 'Glasgow, Scotland',
 'Bournemouth, England',
 'Portsmouth, England',
 'Birmingham, England',
 'Falmouth, England',
 'Durham, England',
 'Nottingham, England',
 'Southampton, England',
 'York, England',
 'St Andrews, Scotland',
 'Leeds, England',
 'Oxford, England',
 'Manchester, England',
 'Winchester, England',
 'Reading, England',
 'Bath, England',
 'Edinburgh, Scotland',
 'Bristol, England',
 'Guildford, England',
 'Exeter, England',
 'Brighton, England',
 'South West London, England',
 'West London, England',
 'Central London, England',
 'North London, England',
 'South East London, England',
 'East London, England']

# %%
# Create a DataFrame with two columns
df = pd.DataFrame([entry.split(', ') for entry in cities2], columns=['City', 'Country'])

# Display the DataFrame
print(df)
# Out:
#                  City  Country
# 0          Carmarthen    Wales
# 1            Bradford  England
# 2              Bolton  England
# 3            Carlisle  England
# 4          Sunderland  England
# ..                ...      ...
# 71        West London  England
# 72     Central London  England
# 73       North London  England
# 74  South East London  England
# 75        East London  England
#
# [76 rows x 2 columns]
